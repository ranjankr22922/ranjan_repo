# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjankr22922/ranjan_repo/blob/main/Data_Science_Bootcamp_by_LetsUpgrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Data Science Bootcamp")
# Out:
# Data Science Bootcamp

# %% [markdown]
# #Dictionary & List

# %%
dict1={"Name":"Ranjan","Course":"MCA-AIML"}
dict1
# Out:
# {'Name': 'Ranjan', 'Course': 'MCA-AIML'}

# %%
dict1["Name"]
# Out:
# 'Ranjan'

# %%
dict1["Name"]="Ranjan Kumar"
dict1["Name"]
# Out:
# 'Ranjan Kumar'

# %%
    list1=[1,2,3,4,5]
    list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list1[2]=6
list1
# Out:
# [1, 2, 6, 4, 5]

# %%
list1[-1]=7
list1
# Out:
# [1, 2, 6, 4, 7]

# %%
list1.append(8)
list1
# Out:
# [1, 2, 6, 4, 7, 8]

# %%
list2=[11,10,9]
list1+list2
# Out:
# [1, 2, 6, 4, 7, 8, 11, 10, 9]

# %%
list1.append(list2)
list1
# Out:
# [1, 2, 6, 4, 7, 8, [11, 10, 9]]

# %%
list1.extend(list2)
list1
# Out:
# [1, 2, 6, 4, 7, 8, [11, 10, 9], 11, 10, 9]

# %% [markdown]
# #If Else

# %%
a=5
b=2

# %%
if a>b:
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# a is greater than b

# %% [markdown]
# #For Loop

# %%
list14=[1,2,3,4,5,6,7]

# %%
for number in list14:
  print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
fruits=["apple", "banana", "cherry"]
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
for fruit in fruits:
  # print(fruit)
  if fruit=="banana":
    print(fruit)
  else:
    print("Banana is not in the list")
# Out:
# Banana is not in the list
# banana
# Banana is not in the list

# %%
for fruit in fruits:
  if fruit=="banana":
    print(fruit)
    break
  else:
    print(fruit)
# Out:
# apple
# banana

# %% [markdown]
# While Loop

# %%
i=1
while(i<6):
  print(i)
  i+=1
  if i==5:
    break
# Out:
# 1
# 2
# 3
# 4

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("Mango")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'Mango']

# %%
fruits.remove("Mango")
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("mango")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
new_fruits=[]
for i in fruits:
  if "mango" == i:
    new_fruits.append(i)
new_fruits
# Out:
# ['mango']

# %%
new_list=[fruit for fruit in fruits if "mango" == fruit]
new_list  #list comprehension
# Out:
# ['mango']

# %%
for i in fruits:
  print(type(i))
  print(i.upper())
# Out:
# <class 'str'>
# APPLE
# <class 'str'>
# BANANA
# <class 'str'>
# CHERRY
# <class 'str'>
# MANGO

# %%
type(fruits)
# Out:
# list

# %%
dict1={"Satyam":"ML Eng", "Harshit":"Sales", "Rahul":"HR", "Tanya": "SE"}
dict1
# Out:
# {'Satyam': 'ML Eng', 'Harshit': 'Sales', 'Rahul': 'HR', 'Tanya': 'SE'}

# %%
dict1.items()
# Out:
# dict_items([('Satyam', 'ML Eng'), ('Harshit', 'Sales'), ('Rahul', 'HR'), ('Tanya', 'SE')])

# %%
for key, value in dict1.items():
  print("Key : ",key)
  print("Value : ",value)
  print("\n")
# Out:
# Key :  Satyam
# Value :  ML Eng
#
#
# Key :  Harshit
# Value :  Sales
#
#
# Key :  Rahul
# Value :  HR
#
#
# Key :  Tanya
# Value :  SE

# %%
keys=["a","b","c"]
values=[1,2,3]
v1=[9,8,7]

# %%
{k:v for (k,v) in zip(keys,values)}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
for i,j,k in zip(keys,values,v1):
  print(i,j,k)
# Out:
# a 1 9
# b 2 8
# c 3 7

# %%
# !unzip "/content/archive.zip"
# Out:
# Archive:  /content/archive.zip
#   inflating: election_results_2024.csv

# %% [markdown]
# #Pandas

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/election_results_2024.csv')

# %%
df
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# ...

# %%
# df=df.drop_duplicates()
# df

df.drop_duplicates(inplace=True)
df
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# ...

# %%
df.head()
# Out:
#        Constituency  Const. No.    Leading Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV
# 2            AMBALA           1       VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN
#
#                          Leading Party    Trailing Candidate  \
# 0               Bharatiya Janata Party  RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party           LALIT YADAV
# 2             Indian National Congress         BANTO KATARIA
# 3  Jammu & Kashmir National Conference        MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam             L VIJAYAN
#
#                              Trailing Party  Margin           Status
# 0                  Indian National Congress  329991  Result Declared
# 1                  Indian National Congress   48282  Result Declared
# ...

# %%
df.tail()
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 538  Nationalist Congress Party – Sharadchandra Pawar
# 539                          Indian National Congress
# 540                            Bharatiya Janata Party
# 541             Shiv Sena (Uddhav Balasaheb Thackrey)
# 542                          Indian National Congress
#
#                     Trailing Candidate            Trailing Party  Margin  \
# 538           RAMDAS CHANDRABHAN TADAS    Bharatiya Janata Party   81648
# 539                         ANNIE RAJA  Communist Party of India  364422
# ...

# %%
df.head(10)
# Out:
#        Constituency  Const. No.              Leading Candidate  \
# 0             AJMER          13            BHAGIRATH CHOUDHARY
# 1             ALWAR           8                BHUPENDER YADAV
# 2            AMBALA           1                 VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3               MIAN ALTAF AHMAD
# 4         ARAKKONAM           7              S JAGATHRATCHAKAN
# 5             ARANI          12             THARANIVENTHAN M S
# 6          Adilabad           1                   GODAM NAGESH
# 7              Agra          18          PROF S P SINGH BAGHEL
# 8    Ahmedabad East           7  HASMUKHBHAI PATEL (H.S.PATEL)
# 9    Ahmedabad West           8  DINESHBHAI MAKWANA (ADVOCATE)
#
#                          Leading Party            Trailing Candidate  \
# 0               Bharatiya Janata Party          RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party                   LALIT YADAV
# ...

# %%
df[['Leading Party','Margin','Status','Constituency']]
# Out:
#                                         Leading Party  Margin  \
# 0                              Bharatiya Janata Party  329991
# 1                              Bharatiya Janata Party   48282
# 2                            Indian National Congress   49036
# 3                 Jammu & Kashmir National Conference  281794
# 4                           Dravida Munnetra Kazhagam  306559
# ..                                                ...     ...
# 538  Nationalist Congress Party – Sharadchandra Pawar   81648
# 539                          Indian National Congress  364422
# 540                            Bharatiya Janata Party  199013
# 541             Shiv Sena (Uddhav Balasaheb Thackrey)   94473
# 542                          Indian National Congress   46188
#
#               Status      Constituency
# 0    Result Declared             AJMER
# 1    Result Declared             ALWAR
# 2    Result Declared            AMBALA
# 3    Result Declared  ANANTNAG-RAJOURI
# ...

# %%
# df['Margin'].mean()

# %%
# df.groupby("Leading Party")['Margin'].mean()

# %% [markdown]
# #Data Analysis & Visualization

# %%
pd.read_csv('/content/archive (1).zip')
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# !unzip '/content/archive (1).zip'
# Out:
# Archive:  /content/archive (1).zip
#   inflating: adult.csv

# %%
df=pd.read_csv('/content/adult.csv')

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df=df.drop_duplicates()
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.isna() #True shows the null values in the dataset
# Out:
#          age  workclass  fnlwgt  education  education.num  marital.status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital.gain  capital.loss  \
# ...

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education.num   32537 non-null  int64
#  5   marital.status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    32537 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital.gain    32537 non-null  int64
#  11  capital.loss    32537 non-null  int64
#  12  hours.per.week  32537 non-null  int64
#  13  native.country  32537 non-null  object
#  14  income          32537 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df_obj = df.select_dtypes("object") #non-numerical data
df_obj
# Out:
#       workclass     education      marital.status         occupation  \
# 0             ?       HS-grad             Widowed                  ?
# 1       Private       HS-grad             Widowed    Exec-managerial
# 2             ?  Some-college             Widowed                  ?
# 3       Private       7th-8th            Divorced  Machine-op-inspct
# 4       Private  Some-college           Separated     Prof-specialty
# ...         ...           ...                 ...                ...
# 32556   Private  Some-college       Never-married    Protective-serv
# 32557   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   Private       HS-grad             Widowed       Adm-clerical
# 32560   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex native.country income
# 0      Not-in-family  White  Female  United-States  <=50K
# ...

# %%
import seaborn as sns

# %%
sns.countplot(df_obj['workclass'])
# Out:
# <Axes: xlabel='count', ylabel='workclass'>

# %%
df.select_dtypes(exclude='object')  #numerical data only
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0       90   77053              9             0          4356              40
# 1       82  132870              9             0          4356              18
# 2       66  186061             10             0          4356              40
# 3       54  140359              4             0          3900              40
# 4       41  264663             10             0          3900              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   22  310152             10             0             0              40
# 32557   27  257302             12             0             0              38
# 32558   40  154374              9             0             0              40
# 32559   58  151910              9             0             0              40
# 32560   22  201490              9             0             0              20
#
# [32537 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.countplot(df_obj,x ='workclass')
# Out:
# <Axes: xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=((15,8)))
sns.countplot(df_obj, x='workclass')
# Out:
# <Axes: xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df_obj,x='workclass')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, '?'),
#   Text(1, 0, 'Private'),
#   Text(2, 0, 'State-gov'),
#   Text(3, 0, 'Federal-gov'),
#   Text(4, 0, 'Self-emp-not-inc'),
#   Text(5, 0, 'Self-emp-inc'),
#   Text(6, 0, 'Local-gov'),
#   Text(7, 0, 'Without-pay'),
#   Text(8, 0, 'Never-worked')])

# %%
df_obj.columns
# Out:
# Index(['workclass', 'education', 'marital.status', 'occupation',
#        'relationship', 'race', 'sex', 'native.country', 'income'],
#       dtype='object')

# %%
len(df_obj.columns)
# Out:
# 9

# %%
plt.figure(figsize=(18,30))
for i in range (len(df_obj.columns)):
  plt.subplot(5,2,i+1)
  sns.countplot(df_obj[df_obj.columns[i]])
  plt.title(f"Countplot of {df_obj.columns[i]}")
  plt.xticks(rotation=45)
  plt.tight_layout()

# %%
df_int=df.select_dtypes(exclude="object")
df_int
# Out:
#        age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0       90   77053              9             0          4356              40
# 1       82  132870              9             0          4356              18
# 2       66  186061             10             0          4356              40
# 3       54  140359              4             0          3900              40
# 4       41  264663             10             0          3900              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   22  310152             10             0             0              40
# 32557   27  257302             12             0             0              38
# 32558   40  154374              9             0             0              40
# 32559   58  151910              9             0             0              40
# 32560   22  201490              9             0             0              20
#
# [32537 rows x 6 columns]

# %%
sns.distplot(df_int['age'])
# Out:
# <ipython-input-30-18dca5cf9113>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_int['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
df_int.columns
# Out:
# Index(['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss',
#        'hours.per.week'],
#       dtype='object')

# %%
len(df_int.columns)
# Out:
# 6

# %%
plt.figure(figsize=(18,30))
for i in range (len(df_int.columns)):
  plt.subplot(5,2,i+1)
  sns.distplot(df_int[df_int.columns[i]])
  plt.title(f"Countplot of {df_int.columns[i]}")
  plt.xticks(rotation=45)
  plt.tight_layout()
# Out:
# <ipython-input-35-9a74a2a2ca20>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_int[df_int.columns[i]])
# <ipython-input-35-9a74a2a2ca20>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_int[df_int.columns[i]])
# ...

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
sns.stripplot(x=df['income'],y=df['age'])
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
sns.stripplot(x=df['income'],y=df['education'])
# Out:
# <Axes: xlabel='income', ylabel='education'>

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df['age']
# Out:
# 0        90
# 1        82
# 2        66
# 3        54
# 4        41
#          ..
# 32556    22
# 32557    27
# 32558    40
# 32559    58
# 32560    22
# Name: age, Length: 32537, dtype: int64

# %%
df['age'].min()
# Out:
# 17

# %%
df['age'].max()
# Out:
# 90

# %%
df['age'].mean()
# Out:
# 38.585548759873376

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['age'].mode()
# Out:
# 0    36
# Name: age, dtype: int64

# %%
df['age'].var() #Variance
# Out:
# 185.99459445005203

# %%
df['age'].skew()
# Out:
# 0.5576631514973126

# %%
df.shape  #Rows & Columns
# Out:
# (32537, 15)

# %%
list49=[1,2,3,5,6,6,7,5,5,10]
median=(6+6)//12
mode=5 #most occured elemnt

# %% [markdown]
# #Machine Learning

# %%
data = {
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029],
    'Price_of_Petrol': [45, 49, 53, 55, 60, 70, 75, 80, 83, 85, 88, 90, 92, 95, 96, 97, 98, 99, 105, 107]
}

df=pd.DataFrame(data)
print(df)
# Out:
#     Year  Price_of_Petrol
# 0   2010               45
# 1   2011               49
# 2   2012               53
# 3   2013               55
# 4   2014               60
# 5   2015               70
# 6   2016               75
# 7   2017               80
# 8   2018               83
# 9   2019               85
# 10  2020               88
# 11  2021               90
# 12  2022               92
# 13  2023               95
# 14  2024               96
# 15  2025               97
# 16  2026               98
# 17  2027               99
# 18  2028              105
# 19  2029              107

# %%
df.plot(x="Price_of_Petrol",y="Year",kind="scatter")
# Out:
# <Axes: xlabel='Price_of_Petrol', ylabel='Year'>

# %%
import numpy as np

# %%
x = np.array(df[['Year']])
y = np.array(df[['Price_of_Petrol']])

# %%
x
# Out:
# array([[2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019],
#        [2020],
#        [2021],
#        [2022],
#        [2023],
#        [2024],
#        [2025],
#        [2026],
#        [2027],
#        [2028],
#        [2029]])

# %%
y
# Out:
# array([[ 45],
#        [ 49],
#        [ 53],
#        [ 55],
#        [ 60],
#        [ 70],
#        [ 75],
#        [ 80],
#        [ 83],
#        [ 85],
#        [ 88],
#        [ 90],
#        [ 92],
#        [ 95],
#        [ 96],
#        [ 97],
#        [ 98],
#        [ 99],
#        [105],
#        [107]])

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
reg.predict([[2035]])
# Out:
# array([[130.56015038]])

# %%
reg.fit(y,x)
# Out:
# LinearRegression()

# %%
int(reg.predict([[150]]))
# Out:
# <ipython-input-166-a5e79d39eaed>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   int(reg.predict([[150]]))
# 2039
